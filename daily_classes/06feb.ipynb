# %%
file=open('cgc_winter.txt','w')

# %%
file.write('hello')
# Out:
# 5

# %%
file.close()

# %%
file=open('new_cgc_winter.txt','w')

# %%
file.write('i am here')
# Out:
# 9

# %%
file.close()

# %%
file=open('new_cgc_winter.txt','w')

# %%
file.write('new data')
# Out:
# 8

# %%
file.close()

# %%
file=open('new_cgc_winter.txt','a')

# %%
file.write('\nthis is new line')
# Out:
# 17

# %%
file.close()

# %%
file=open('new_cgc_winter.txt','a')

# %%
file.write('this is new line\n')
# Out:
# 17

# %%
file.close()

# %%
file=open('new_cgc_winter.txt','r')

# %%
read=file.read()

# %%
print(read)
# Out:
# new data
# this is new linethis is new line/nthis is new line
# this is new line
# king is here
# parrot files
# sd
# sdd
# wss
# sd
# ds
# sd
# sds

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
file.seek(0)
# Out:
# 0

# %%
content=file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 content=file.read()
#
# ValueError: I/O operation on closed file.

# %%
print(content)
# Out:
# new data
# this is new linethis is new line/nthis is new line
# this is new line

# %%
for i in file:
    print(i)

# %%
file.close()

# %%
file=open('new_cgc_winter.txt','r')
for i in file:
    print(i.strip())
file.close()
# Out:
# new data
# this is new linethis is new line/nthis is new line
# this is new line

# %%
with open('new_cgc_winter.txt','a') as f:
    a=int(input('number of lines'))
    for i in range(a):
        data=input()
        f.write(data+'\n')
# Out:
# number of lines 5
#  wss
#  sd
#  ds
#  sd
#  sds

# %%
with open('new_cgc_winter.txt','r') as f:
    new_content=f.read()
    print(f.read())

# %%
print(new_content)
# Out:
# new data
# this is new linethis is new line/nthis is new line
# this is new line
# king is here
# parrot files
# sd
# sdd
# wss
# sd
# ds
# sd
# sds

# %%
with open('new_cgc_winter.txt','r') as f:
    part=f.read()
    print(part)
# Out:
# new data
# this is new linethis is new line/nthis is new line
# this is new line
# king is here
# parrot files
# sd
# sdd
# wss
# sd
# ds
# sd
# sds

# %%
with open('new_cgc_winter.txt','r') as f:
    part=f.read(30)
    print(part)
# Out:
# new data
# this is new linethis

# %%
count=0
with open('new_cgc_winter.txt','r') as f:
    for line in f:
        count+=1
    print('total lines',count)
# Out:
# total lines 12

# %%
lst1=['king','queen','sing','ping','ding']

# %%
file=open('check_file.txt','w')

# %%
file.close()

# %%
with open('check_file.txt','w') as f:
    for ln in lst1: f.write(ln+'\n')

# %%
with open('check_file.txt','r') as f:
    part=f.read()
    print(part)
# Out:
# king
# queen
# sing
# ping
# ding

# %%
names=[]

# %%
with open('check_file.txt','r') as f:
    for ln in f:
        names.append(ln.strip())

# %%
print(names)
# Out:
# ['king', 'queen', 'sing', 'ping', 'ding']

# %%
users=['king','queen','sing']
passwords=['123','456','789']

# %%
with open('auth.txt','w') as f:
    for u,p in zip(users,passwords):
        f.write(f"{u},{p}\n")

# %%
users1=[]
passwords1=[]

# %%
with open('auth.txt','r') as f:
    for line in f:
        u,p = line.strip().split(",")
        users1.append(u)
        passwords1.append(p)

# %%
print(users1)
# Out:
# ['king', 'queen', 'sing']

# %%
print(passwords1)
# Out:
# ['123', '456', '789']

# %%
## use it to build calculator to save data

def calculate(a, b, op):
    if op == '+':
        return a + b
    elif op == '-':
        return a - b
    elif op == '*':
        return a * b
    elif op == '/':
        if b != 0:
            return a / b
        else:
            return "Error: Division by zero"
    else:
        return "Invalid operation"


# Take input
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operation (+, -, *, /): ")

# Calculate result
result = calculate(num1, num2, operator)

# Save result to file
with open("calculator_history.txt", "a") as file:
    file.write(f"{num1} {operator} {num2} = {result}\n")

print("Result:", result)

# Read history
print("\nCalculation History:")
with open("calculator_history.txt", "r") as file:
    print(file.read())
