# %%
a=20
b=10

# %%
c=a+b
print (c)
# Out:
# 30

# %%
# a is redeclared
a=99

# %%
# variable naming rules#can not use special charcter
age$=1
# Out:
#   Cell In[12], line 2
#     age$=1
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##

# %%
age_=12

# %%
age=12

# %%
AGE=2

# %%
1age=12
# Out:
#   Cell In[16], line 1
#     1age=12
#     ^
# SyntaxError: invalid decimal literal

# %%
del a

# %%
a=12
print = a

# %%
age_=32
print(age_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 age_=32
# ----> 2 print(age_)
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
name=age_
print(name)
# Out:
# 32

# %%
name='harsh'

# %%
print(name)
# Out:
# harsh

# %%
print('my name is ',name)
# Out:
# my name is  harsh

# %%
print('hello world')
# Out:
# hello world

# %%
x=2
y='thakur'
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 3
#       1 x=2
#       2 y='thakur'
# ----> 3 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
z='2'

# %%
print(z+y)
# Out:
# 2thakur

# %%
print(str(x)+y)
# Out:
# 2thakur

# %%
print(x,y,z)
# Out:
# 2 thakur 2

# %%
type(x)
# Out:
# int

# %%
print(x+int(z))
# Out:
# 4

# %%
z=int(z)

# %%
type(z)
# Out:
# int

# %%
x = float(input("This is the value of x: "))
y = float(input("This is the value of y: "))
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# This is the value of x:  55
# This is the value of y:  5
# 60.0
# 50.0
# 275.0
# 11.0

# %%
aa=5
bb='raja'

# %%
print(str(aa)+bb)
# Out:
# 5raja

# %%
type(aa)
# Out:
# int

# %%
cc=22.55

# %%
type(cc)
# Out:
# float

# %%
dd=int(cc)

# %%
print(dd)
# Out:
# 22

# %%
ee='123gfhf'

# %%
cities='''jaunpur
mohali
mandi'''

# %%
print(cities)
# Out:
# jaunpur
# mohali
# mandi

# %%
city2='jaunpur\n mohali\n mandi'

# %%
print(city2)
# Out:
# jaunpur
#  mohali
#  mandi

# %%
city3=r'jaunpur\mohali\mandi'

# %%
print(city3)
# Out:
# jaunpur\mohali\mandi

# %%
value = '\u0939\u0930\u094d\u0937 \u0938\u093f\u0902\u0939'
print(value)
# Out:
# हर्ष सिंह

# %%
value = '\u0915\u0928\u093f\u0937\u094d\u0915\u093e'
print(value)
# Out:
# कनिष्का

# %%
value = '\u0907\u0924\u093f\u0936\u093e \u0930\u093e\u0923\u093e \u091c\u0940 '
print(value)
# Out:
# इतिशा राणा जी
