# %%
list1=[]

# %%
type(list1)
# Out:
# list

# %%
list2=['RANA','PAHADAN','MANDI',420,9211]
print(list2)
# Out:
# ['RANA', 'PAHADAN', 'MANDI', 420, 9211]

# %% [markdown]
# ## MODIFYING THE LIST
#
# 1. INDEX METHOD
# 2. COUNT METHOD
# 3. SORT METHOD
# 4. APPEND METHOD
# 5. REMOVE METHOD
# 6. POP METHOD
# 7. EXTEND METHOD
# 8. INSERT METHOD

# %%
print(list2[1])
# Out:
# PAHADAN

# %%
print(list2[-1])
# Out:
# 9211

# %%
# slicing
print(list2[1:3])
# Out:
# ['PAHADAN', 'MANDI']

# %%
print(list2[1:])
# Out:
# ['PAHADAN', 'MANDI', 420, 9211]

# %%
print(list2[:3])
# Out:
# ['RANA', 'PAHADAN', 'MANDI']

# %% [markdown]
# ## Update the value using index

# %%
list2[2]='fake'

# %%
print(list2)
# Out:
# ['RANA', 'PAHADAN', 'fake', 420, 9211]

# %% [markdown]
# #### INDEXING METHOD

# %%
list2.index('PAHADAN')
# Out:
# 1

# %%
list3=['RAJA','MANTRI','CHOR','SIPAHI','SAB','HAI','CHOR','RAJA','MANTRI','CHOR','SIPAHI']

# %%
print(list3)
# Out:
# ['RAJA', 'MANTRI', 'CHOR', 'SIPAHI', 'SAB', 'HAI', 'CHOR', 'RAJA', 'MANTRI', 'CHOR', 'SIPAHI']

# %%
list3.index('RAJA',2)
# Out:
# 7

# %%
list3.index('RAJA',2,5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 list3.index('RAJA',2,5)
#
# ValueError: 'RAJA' is not in list

# %%
list3.index('RAJA',2,9)
# Out:
# 7

# %% [markdown]
# ##### COUNT METHOD

# %%
list3.count('RAJA')
# Out:
# 2

# %%
list4=[33,22,1,34,45,13,12,99]

# %% [markdown]
# #### SORT METHOD

# %%
list4.sort()
print(list4)
# Out:
# [1, 12, 13, 22, 33, 34, 45, 99]

# %%
list5=[33,22,1,34,45,13,12,99]

# %%
list5.sort(reverse=True)

# %%
print(list5)
# Out:
# [99, 45, 34, 33, 22, 13, 12, 1]

# %%
list6=[33,22,1,34,45,13,12,99]
print(sorted(list6))
# Out:
# [1, 12, 13, 22, 33, 34, 45, 99]

# %% [markdown]
# #### APPEND LIST

# %%
print(list6)
# Out:
# [33, 22, 1, 34, 45, 13, 12, 99]

# %%
list6.append(34)

# %%
print(list6)
# Out:
# [33, 22, 1, 34, 45, 13, 12, 99, 34]

# %% [markdown]
# #### remove list

# %%
list6.remove(33)

# %%
print(list6)
# Out:
# [22, 1, 34, 45, 13, 12, 99, 34]

# %% [markdown]
# #### POP METHOD

# %%
list3
# Out:
# ['RAJA',
#  'MANTRI',
#  'CHOR',
#  'SIPAHI',
#  'SAB',
#  'HAI',
#  'CHOR',
#  'RAJA',
#  'MANTRI',
#  'CHOR',
#  'SIPAHI']

# %%
list3.index('CHOR')
# Out:
# 2

# %%
list3.pop(2)
# Out:
# 'CHOR'

# %%
print(list3)
# Out:
# ['RAJA', 'MANTRI', 'SIPAHI', 'SAB', 'HAI', 'CHOR', 'RAJA', 'MANTRI', 'CHOR', 'SIPAHI']

# %% [markdown]
# #### EXTEND METHOD

# %%
list3.extend([1,2,3,])

# %%
print(list3)
# Out:
# ['RAJA', 'MANTRI', 'SIPAHI', 'SAB', 'HAI', 'CHOR', 'RAJA', 'MANTRI', 'CHOR', 'SIPAHI', 1, 2, 3]

# %% [markdown]
# #### INSERT

# %%
list3.insert(3,'WE HAVE USE INSERT METHOD')

# %%
print(list3)
# Out:
# ['RAJA', 'MANTRI', 'SIPAHI', 'WE HAVE USE INSERT METHOD', 'SAB', 'HAI', 'CHOR', 'RAJA', 'MANTRI', 'CHOR', 'SIPAHI', 1, 2, 3]

# %%
list3.insert(3,list4)

# %%
print(list3)
# Out:
# ['RAJA', 'MANTRI', 'SIPAHI', [1, 12, 13, 22, 33, 34, 45, 99], 45, 'WE HAVE USE INSERT METHOD', 'SAB', 'HAI', 'CHOR', 'RAJA', 'MANTRI', 'CHOR', 'SIPAHI', 1, 2, 3]

# %%
print(list3[3][0:1])
# Out:
# [1]

# %%
list7=[1,2,3,4,5]

# %%
list8=['a','b']

# %%
list7.insert(3,list8)
print(list7)
# Out:
# [1, 2, 3, ['a', 'b'], 4, 5]

# %%
print(list7[3])
# Out:
# ['a', 'b']

# %%
list7[3].append('bss karo')

# %%
print(list7)
# Out:
# [1, 2, 3, ['a', 'b', 'bss karo'], 4, 5]

# %%
name='harsh'

# %%
list7.append(name)
print(list7)
# Out:
# [1, 2, 3, ['a', 'b', 'bss karo'], 4, 5, 'harsh']

# %%
surname='thakur'
list7.insert(6,surname)
print(list7)
# Out:
# [1, 2, 3, ['a', 'b', 'bss karo'], 4, 5, 'thakur', 'harsh']

# %%
list7.pop(3)
# Out:
# ['a', 'b', 'bss karo']

# %%
print(list7)
# Out:
# [1, 2, 3, 4, 5, 'thakur', 'harsh']

# %% [markdown]
# # TUPLE

# %%
tup=('kin','queen','sdbids','hbshbsi')
print(tup)
# Out:
# ('kin', 'queen', 'sdbids', 'hbshbsi')

# %%
type(tup)
# Out:
# tuple

# %%
tup[3]
# Out:
# 'hbshbsi'

# %%
tup.count('queen')
# Out:
# 1

# %%
tup.index('queen')
# Out:
# 1

# %%
x=list(tup)
print(x)
# Out:
# ['kin', 'queen', 'sdbids', 'hbshbsi']

# %%
type(x)
# Out:
# list

# %%
x=tuple(x)
type(x)
# Out:
# tuple

# %% [markdown]
# # DICTIONARY

# %%
std={'name':'harsh','contact':8400638111}
print(std)
# Out:
# {'name': 'harsh', 'contact': 8400638111}

# %%
print(std['name'])
# Out:
# harsh

# %%
std['address']='jaunpur'

# %%
print(std['address'])
# Out:
# jaunpur

# %%
std.update({'name':'Thakur Harsh Singh','contact':9451665663})
print(std)
# Out:
# {'name': 'Thakur Harsh Singh', 'contact': 9451665663, 'address': 'jaunpur'}

# %%
std.pop('address')
# Out:
# 'jaunpur'

# %%
print(std)
# Out:
# {'name': 'Thakur Harsh Singh', 'contact': 9451665663}

# %%
del std['name']

# %%
print(std)
# Out:
# {'contact': 9451665663}

# %%
std.update({'subject':'data sceince'})

# %%
print(std)
# Out:
# {'contact': 9451665663, 'subject': 'data sceince'}

# %%
print(std.get('name')
# Out:
#   Cell In[29], line 1
#     print(std.get('name')
#                          ^
# SyntaxError: incomplete input

# %%
print(std.get('contact','can not find it'))
# Out:
# 9451665663

# %%
print(std.get('name','can not find it'))
# Out:
# can not find it

# %% [markdown]
# ##### nested dictionary

# %%
stds={
    'std1':{'name':'harsh','roll_no':2236804},
    'std2':{'name':'rana','roll_no':2236823},
    'std3':{'name':'isha','roll_no':2236818}
    
}

# %%
print(stds['std1']['name'])
# Out:
# harsh

# %%
print(len(stds))
# Out:
# 3

# %%
print(len(stds['std1']))
# Out:
# 2

# %%
stds.keys()
# Out:
# dict_keys(['std1', 'std2', 'std3'])

# %%
stds.values()
# Out:
# dict_values([{'name': 'harsh', 'roll_no': 2236804}, {'name': 'rana', 'roll_no': 2236823}, {'name': 'isha', 'roll_no': 2236818}])

# %%
stds.items()
# Out:
# dict_items([('std1', {'name': 'harsh', 'roll_no': 2236804}), ('std2', {'name': 'rana', 'roll_no': 2236823}), ('std3', {'name': 'isha', 'roll_no': 2236818})])

# %%
'std4' in stds
# Out:
# False

# %%
'std3' in stds
# Out:
# True

# %%
'name' in stds['std1'].keys()
# Out:
# True

# %%
'harsh' in stds['std1'].values()
# Out:
# True

# %% [markdown]
# #### set

# %%
set1={22,1,1,2,3,4,5,6,7}

# %%
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 22}

# %%
set1.pop()
# Out:
# 1

# %%
set1.update({1})

# %%
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 22}

# %%
set1.remove(22)

# %%
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
lst = [1, 2, 3, 2, 4, 1]
s = set(lst)
print(s)
# Out:
# {1, 2, 3, 4}

# %%
lst2 = list(s)
print(lst2)
# Out:
# [1, 2, 3, 4]

# %%
## string methods

# %%
name = "harsh singh"
print(name.upper())
# Out:
# HARSH SINGH

# %%
name = "Harsh Singh"
print(name.lower())
# Out:
# harsh singh

# %%
name = input("Enter your name: ")
print(name.upper())
# Out:
# Enter your name:  harsh
# HARSH

# %%
name = input("Enter your name: ")
print(name.lower())
# Out:
# Enter your name:  HEHHE
# hehhe

# %%
name = input("Enter your name: ")
print(name.capitalize())
# Out:
# Enter your name:  harsh
# Harsh

# %%
sentence = "   Python is very easy to learn   "
clean_sentence = sentence.strip()

print(clean_sentence)
# Out:
# Python is very easy to learn

# %%
sentence = "Python is very easy to learn"
words = sentence.split()

print(words)
# Out:
# ['Python', 'is', 'very', 'easy', 'to', 'learn']

# %%
sentence = "Python is easy and Python is powerful"
result = sentence.count("Python")

print(result)
# Out:
# 2

# %%
words = ["Python", "is", "easy"]
sentence = " ".join(words)

print(sentence)
# Out:
# Python is easy

# %%
text = "Python"
print(text.isalpha())
# Out:
# True
